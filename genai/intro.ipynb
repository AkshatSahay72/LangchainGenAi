# %% [markdown]
# # Langchain V1

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.2.15

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 2
#       1 import os
# ----> 2 from dotenv import load_dotenv
#       3 load_dotenv()
#       4
#
# ImportError: cannot import name 'load_dotenv' from 'dotenv' (d:\Coding\GenAi Agentic Ai\LangchainGenAi\.venv\Lib\site-packages\dotenv\__init__.py)
