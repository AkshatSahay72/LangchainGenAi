# %% [markdown]
# # Messages
# * Role
# * Content
# * Metadata

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model = init_chat_model("groq:llama-3.1-8b-instant")

# %%
model.invoke("Please tell me something about AI")
# Out:
# AIMessage(content="Artificial Intelligence (AI) is a broad and rapidly evolving field that involves the creation of intelligent machines that can perform tasks that would typically require human intelligence, such as:\n\n1. **Learning**: AI systems can learn from data, experiences, and interactions.\n2. **Reasoning**: AI systems can draw conclusions, make decisions, and solve problems.\n3. **Perception**: AI systems can interpret and understand data from sensors, images, and natural language.\n4. **Action**: AI systems can interact with the physical world, control robots, and execute tasks.\n\nTypes of AI:\n\n1. **Narrow or Weak AI**: Designed to perform a specific task, such as image recognition, language translation, or playing chess.\n2. **General or Strong AI**: A hypothetical AI system that possesses human-like intelligence and can perform any intellectual task.\n3. **Superintelligence**: An AI system that surpasses human intelligence in all domains.\n\nApplications of AI:\n\n1. **Virtual Assistants**: Siri, Google Assistant, Alexa, and Cortana use AI to understand voice commands and respond accordingly.\n2. **Image and Speech Recognition**: AI-powered systems can recognize faces, objects, and spoken words.\n3. **Recommendation Systems**: AI-driven algorithms suggest products, services, or content based on user behavior and preferences.\n4. **Healthcare**: AI is used in medical diagnosis, personalized medicine, and patient care.\n5. **Autonomous Vehicles**: AI enables self-driving cars to navigate roads, detect obstacles, and adapt to changing situations.\n\nBenefits of AI:\n\n1. **Increased Efficiency**: AI automates tasks, freeing up time for more strategic and creative work.\n2. **Improved Accuracy**: AI systems can perform tasks with higher accuracy and speed than humans.\n3. **Enhanced Decision-Making**: AI provides data-driven insights and recommendations to inform decision-making.\n4. **New Business Opportunities**: AI enables the creation of new products, services, and business models.\n\nHowever, AI also raises concerns about:\n\n1. **Job Displacement**: AI may automate jobs, potentially leading to unemployment.\n2. **Bias and Fairness**: AI systems can perpetuate existing biases and discriminatory practices.\n3. **Security and Privacy**: AI systems can be vulnerable to cyber attacks and data breaches.\n4. **Accountability and Responsibility**: As AI makes decisions, it's essential to establish clear accountability and responsibility.\n\nOverall, AI has the potential to transform industries, improve lives, and create new opportunities. However, it's crucial to address the challenges and concerns associated with AI to ensure its development and deployment are responsible and beneficial to society.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 526, 'prompt_tokens': 41, 'total_tokens': 567, 'completion_time': 0.704889865, 'completion_tokens_details': None, 'prompt_time': 0.002164165, 'prompt_tokens_details': None, 'queue_time': 0.051885771, 'total_time': 0.70705403}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019e12d5-0332-74d0-a645-b8bd0e4e7c91-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 526, 'total_tokens': 567})

# %% [markdown]
# ## Text Prompts

# %%
model.invoke("What is Langchain")
# Out:
# AIMessage(content="LangChain is an open-source framework for building conversational AI applications. It is designed to make it easier to integrate and orchestrate multiple AI models, data sources, and services to create more advanced and contextual conversations.\n\nLangChain allows developers to build conversational interfaces that can interact with users, understand their intent, and respond accordingly. It supports a wide range of AI models and technologies, including natural language processing (NLP), machine learning, and computer vision.\n\nSome key features of LangChain include:\n\n1. **Model Orchestration**: LangChain allows developers to integrate and orchestrate multiple AI models, including NLP, machine learning, and computer vision models.\n2. **Data Integration**: LangChain provides a flexible data management system that enables developers to integrate data from various sources, including databases, APIs, and files.\n3. **Conversational Flow**: LangChain enables developers to define conversational flows that can be used to guide conversations and automate responses.\n4. **Contextual Understanding**: LangChain uses context-aware AI models to understand the user's intent and respond accordingly.\n5. **Scalability**: LangChain is designed to scale with the needs of the application, making it suitable for large-scale conversational AI deployments.\n\nLangChain is built on top of the LLM (Large Language Model) architecture, which enables it to support a wide range of AI models and technologies. Some of the key use cases for LangChain include:\n\n1. **Chatbots**: LangChain can be used to build conversational chatbots that can interact with users and respond to their queries.\n2. **Virtual Assistants**: LangChain can be used to build virtual assistants that can perform tasks, answer questions, and provide recommendations.\n3. **Conversational Interfaces**: LangChain can be used to build conversational interfaces for various applications, including customer service, sales, and marketing.\n4. **Intelligent Virtual Assistants**: LangChain can be used to build intelligent virtual assistants that can learn from user interactions and improve over time.\n\nOverall, LangChain is a powerful framework for building conversational AI applications that can interact with users in a more natural and intuitive way.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 435, 'prompt_tokens': 39, 'total_tokens': 474, 'completion_time': 0.653193247, 'completion_tokens_details': None, 'prompt_time': 0.002857331, 'prompt_tokens_details': None, 'queue_time': 0.066028968, 'total_time': 0.656050578}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019e12d5-13e8-7883-98f5-a925bcfaeb6c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 39, 'output_tokens': 435, 'total_tokens': 474})

# %% [markdown]
# ## Message Prompts

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage

messages = [
    SystemMessage("You are a data science expert"),
    HumanMessage("Explain about RAG application")
]
response = model.invoke(messages)
print(response.content)
# Out:
# **RAG Application Overview**
#
# The RAG (Red, Amber, Green) application is a decision-making framework used in various industries, including manufacturing, logistics, and supply chain management. It is a color-coded system that categorizes data into three primary categories: Red, Amber, and Green.
#
# **What is RAG?**
#
# RAG is an acronym that stands for:
#
# 1. **Red**: Critical or high-risk issues that require immediate attention and resolution.
# 2. **Amber**: Warning or potential issues that require monitoring and investigation.
# 3. **Green**: Normal or satisfactory performance that meets established standards.
#
# **How does RAG work?**
#
# The RAG application involves the following steps:
#
# 1. **Define thresholds**: Establish specific criteria or thresholds for each category (Red, Amber, and Green).
# 2. **Collect and analyze data**: Gather relevant data from various sources and perform analysis to determine the current state.
# 3. **Categorize data**: Assign a color code (Red, Amber, or Green) based on the analysis and comparison with established thresholds.
# 4. **Monitor and review**: Continuously monitor the data and review the RAG status to ensure accuracy and make adjustments as needed.
#
# **RAG Application Uses**
#
# The RAG application is commonly used in:
#
# 1. **Quality control**: Monitor and manage quality issues in manufacturing, such as defects or anomalies.
# 2. **Supply chain management**: Track and analyze inventory levels, lead times, and delivery performance.
# 3. **Logistics**: Monitor transportation, warehousing, and distribution operations.
# 4. **Financial performance**: Analyze financial metrics, such as revenue, expenses, and profitability.
#
# **Benefits of RAG Application**
#
# The RAG application offers several benefits, including:
#
# 1. **Improved decision-making**: Provides a clear and concise visual representation of data, enabling faster and more informed decisions.
# 2. **Enhanced visibility**: Enables stakeholders to quickly identify and address critical issues.
# 3. **Increased efficiency**: Automates the monitoring and analysis process, reducing manual effort and improving productivity.
# 4. **Better communication**: Facilitates effective communication among teams and stakeholders by using a standardized language and framework.
#
# **Example Code (R)**
# ```r
# # Define RAG thresholds
# red_threshold <- 0.5
# amber_threshold <- 0.7
#
# # Example data
# data <- data.frame(
#   Metric = c("Metric1", "Metric2", "Metric3"),
#   Value = c(0.2, 0.8, 0.9)
# )
#
# # Assign RAG color codes
# data$RAG <- ifelse(data$Value > red_threshold, "Green",
#                    ifelse(data$Value > amber_threshold, "Amber", "Red"))
#
# # Print RAG status
# print(data)
# ```
# This example code demonstrates how to define RAG thresholds and assign color codes to example data using R.

# %%
system_msg = SystemMessage("You are a helpful coding assistant")

messages = [
    system_msg,
    HumanMessage("How do I create a REST API")
]

response = model.invoke(messages)

print(response.content)
# Out:
# **Creating a REST API: A Step-by-Step Guide**
#
# A REST (Representational State of Resource) API is an architectural style for designing networked applications. It's a simple way to communicate between systems, and it's widely used for building web services. Here's a step-by-step guide to creating a REST API:
#
# ### Step 1: Choose a Programming Language and Framework
#
# Select a programming language and a framework that you're comfortable with. Some popular choices include:
#
# * **Python**: Flask or Django
# * **Java**: Spring Boot
# * **JavaScript**: Node.js and Express.js
# * **C#**: ASP.NET Core
#
# ### Step 2: Plan Your API
#
# Before you start coding, plan your API's structure and endpoints. Consider the following:
#
# * **API Endpoints**: Define the URLs for your API endpoints, such as `/users`, `/products`, or `/orders`.
# * **HTTP Methods**: Decide which HTTP methods each endpoint will use, such as GET, POST, PUT, or DELETE.
# * **Request and Response Bodies**: Determine the structure of the request and response bodies for each endpoint.
#
# ### Step 3: Set Up Your Development Environment
#
#  Install the necessary dependencies and set up your development environment. For example:
#
# * **Python**: `pip install flask`
# * **Java**: `mvn spring-boot:run`
# * **JavaScript**: `npm install express`
# * **C#**: `dotnet run`
#
# ### Step 4: Implement Your API Endpoints
#
# Create a new file for each endpoint and implement the corresponding logic. For example:
#
# **users.py** (Python with Flask)
# ```python
# from flask import Flask, jsonify, request
#
# app = Flask(__name__)
#
# @app.route('/users', methods=['GET'])
# def get_users():
#     # Return a list of all users
#     users = [{'id': 1, 'name': 'John Doe'}, {'id': 2, 'name': 'Jane Doe'}]
#     return jsonify(users)
#
# @app.route('/users', methods=['POST'])
# def create_user():
#     # Create a new user
#     data = request.json
#     user = {'id': len(users) + 1, 'name': data['name']}
#     users.append(user)
#     return jsonify(user), 201
#
# if __name__ == '__main__':
#     app.run(debug=True)
# ```
#
# ### Step 5: Implement Authentication and Authorization
#
# Implement authentication and authorization mechanisms to secure your API. For example:
#
# * **Basic Authentication**: Use a library like `flask-basicauth` for Python or `spring-security` for Java.
# * **JSON Web Tokens (JWT)**: Use a library like `flask-jwt-extended` for Python or `spring-security-oauth2` for Java.
#
# ### Step 6: Test Your API
#
# Use a tool like `curl` or a REST client like Postman to test your API endpoints. For example:
#
# ```bash
# curl -X GET http://localhost:5000/users
# curl -X POST -H "Content-Type: application/json" -d '{"name": "Bob Smith"}' http://localhost:5000/users
# ```
#
# ### Step 7: Deploy Your API
#
# Deploy your API to a production environment. For example:
#
# * **Cloud Platforms**: Use a cloud platform like AWS, Google Cloud, or Azure.
# * **Containerization**: Use a containerization platform like Docker.
# * **Virtual Private Server (VPS)**: Use a VPS provider like DigitalOcean or Linode.
#
# That's it! With these steps, you've created a basic REST API. Remember to follow best practices for coding, testing, and deployment to ensure your API is robust and maintainable.
#
# ### Example Use Cases
#
# Here are some example use cases for a REST API:
#
# * **E-commerce**: Create a REST API to manage products, orders, and customers.
# * **Social Media**: Create a REST API to manage user profiles, posts, and comments.
# * **Weather API**: Create a REST API to retrieve weather data for a given location.
#
# ### Best Practices
#
# Here are some best practices for creating a REST API:
#
# * **Use HTTP Status Codes**: Use HTTP status codes to indicate the outcome of a request.
# * **Follow API Design Principles**: Follow API design principles like resource-oriented, stateless, and cacheable.
# * **Use Versioning**: Use versioning to manage changes to your API.
# * **Document Your API**: Document your API using tools like Swagger or API Blueprint.
# * **Test Your API**: Test your API thoroughly using tools like Postman or cURL.

# %%
system_msg = SystemMessage("""
You are a senior python developer with expertise in web frameworks.
Always provide code examples and explain your reasoning.
Be concise but thorough in your explainations.""")

messages = [
    system_msg,
    HumanMessage("How do I create a REST API")
]

response = model.invoke(messages)

print(response.content)
# Out:
# **Creating a REST API with Flask**
# =====================================
#
# In this example, we will create a simple REST API using Flask, a popular Python web framework.
#
# ### Step 1: Install Required Packages
#
# First, install Flask using pip:
# ```bash
# pip install flask
# ```
# ### Step 2: Define API Endpoints
#
# Create a new file called `app.py` and define your API endpoints:
# ```python
# from flask import Flask, jsonify, request
#
# app = Flask(__name__)
#
# # Sample in-memory data store
# users = [
#     {"id": 1, "name": "John Doe", "email": "john@example.com"},
#     {"id": 2, "name": "Jane Doe", "email": "jane@example.com"}
# ]
#
# # GET /users
# @app.route('/users', methods=['GET'])
# def get_users():
#     return jsonify(users)
#
# # GET /users/:id
# @app.route('/users/<int:user_id>', methods=['GET'])
# def get_user(user_id):
#     user = next((user for user in users if user['id'] == user_id), None)
#     if user is None:
#         return jsonify({"error": "User not found"}), 404
#     return jsonify(user)
#
# # POST /users
# @app.route('/users', methods=['POST'])
# def create_user():
#     data = request.json
#     new_user = {
#         "id": len(users) + 1,
#         "name": data['name'],
#         "email": data['email']
#     }
#     users.append(new_user)
#     return jsonify(new_user), 201
#
# # PUT /users/:id
# @app.route('/users/<int:user_id>', methods=['PUT'])
# def update_user(user_id):
#     user = next((user for user in users if user['id'] == user_id), None)
#     if user is None:
#         return jsonify({"error": "User not found"}), 404
#     data = request.json
#     user['name'] = data['name']
#     user['email'] = data['email']
#     return jsonify(user)
#
# # DELETE /users/:id
# @app.route('/users/<int:user_id>', methods=['DELETE'])
# def delete_user(user_id):
#     user = next((user for user in users if user['id'] == user_id), None)
#     if user is None:
#         return jsonify({"error": "User not found"}), 404
#     users.remove(user)
#     return jsonify({"message": "User deleted"})
#
# if __name__ == '__main__':
#     app.run(debug=True)
# ```
# ### Step 3: Run the API
#
# Run the API using `python app.py` and test it using a tool like `curl` or a REST client like Postman.
#
# **Example Use Cases:**
#
# * Get all users: `curl http://localhost:5000/users`
# * Get a specific user: `curl http://localhost:5000/users/1`
# * Create a new user: `curl -X POST -H "Content-Type: application/json" -d '{"name": "Bob Smith", "email": "bob@example.com"}' http://localhost:5000/users`
# * Update an existing user: `curl -X PUT -H "Content-Type: application/json" -d '{"name": "Jim Doe", "email": "jim@example.com"}' http://localhost:5000/users/1`
# * Delete a user: `curl -X DELETE http://localhost:5000/users/1`
#
# This is a basic example of a REST API using Flask. You can add more endpoints, validation, and error handling as needed.

# %% [markdown]
# ### Message Metadata

# %%
human_msg = HumanMessage(
    content="Hello",
    name = "alice",
    id = "msg_123"
)

# %%
response = model.invoke([human_msg])
response.content
# Out:
# 'Hello. How can I assist you today?'

# %%
ai_msg = AIMessage("I'd be happy to help you with that questions!")

messages = [
    SystemMessage("You are helpful assistant"),
    HumanMessage("Can you help me?"),
    ai_msg,
    HumanMessage("Great! What's 2+2?")
]

response = model.invoke(messages)
print(response.content)
# Out:
# The answer to 2+2 is 4.

# %%
response.usage_metadata
# Out:
# {'input_tokens': 74, 'output_tokens': 12, 'total_tokens': 86}

# %%
from langchain.messages import ToolMessage

ai_message = AIMessage(
    content=[],
    tool_calls=[{
        "name":"get_weather",
        "args":{"location":"San Francisco"},
        "id":"call_123"
    }]
)

# %%
weather_result = "Sunny, 72 F"
tool_message = ToolMessage(
    content=weather_result,
    tool_call_id="call_123"
)

# %%
messages = [
    HumanMessage("What's the weather in San Francisco?"),
    ai_message,
    tool_message,
]

response = model.invoke(messages)
print(response.content)
# Out:
# Please note that this is a general response, as I'm a text-based AI model and do not have real-time access to current weather conditions. The weather in San Francisco can vary greatly depending on the time of year and other factors. For the most up-to-date and accurate weather information, I recommend checking a reliable weather website or app, such as accuweather.com or weather.com.
