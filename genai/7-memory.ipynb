# %% [markdown]
# ### Agent with memory

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model = init_chat_model("groq:llama-3.1-8b-instant")
model
# Out:
# ChatGroq(output_version=None, profile={'max_input_tokens': 131072, 'max_output_tokens': 8192, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x000001DB7577BA10>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001DB75930830>, model_name='llama-3.1-8b-instant', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

# %%
agent = create_agent(
    model=model,
    checkpointer=InMemorySaver(),
)

# %%
config = {"configurable": {"thread_id": "test1"}}

# %%
from langchain_core.messages import HumanMessage, SystemMessage
response = agent.invoke({'messages':[HumanMessage(content="Hi my name is aki")]}, config=config)
response
# Out:
# {'messages': [HumanMessage(content='Hi my name is aki', additional_kwargs={}, response_metadata={}, id='b7900c75-3da1-469a-bb8a-f00a5e9d7968'),
#   AIMessage(content='Nice to meet you, Aki. Is there something I can help you with today, or would you like to chat?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 41, 'total_tokens': 67, 'completion_time': 0.03822589, 'completion_tokens_details': None, 'prompt_time': 0.003105836, 'prompt_tokens_details': None, 'queue_time': 0.056106754, 'total_time': 0.041331726}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019e2c9f-51da-7bd0-8f22-4193079db0f8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 26, 'total_tokens': 67})]}

# %%
response = agent.invoke({'messages':[HumanMessage(content="What is my name")]}, config=config)
response
# Out:
# {'messages': [HumanMessage(content='Hi my name is aki', additional_kwargs={}, response_metadata={}, id='b7900c75-3da1-469a-bb8a-f00a5e9d7968'),
#   AIMessage(content='Nice to meet you, Aki. Is there something I can help you with today, or would you like to chat?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 41, 'total_tokens': 67, 'completion_time': 0.03822589, 'completion_tokens_details': None, 'prompt_time': 0.003105836, 'prompt_tokens_details': None, 'queue_time': 0.056106754, 'total_time': 0.041331726}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019e2c9f-51da-7bd0-8f22-4193079db0f8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 26, 'total_tokens': 67}),
#   HumanMessage(content='What is my name', additional_kwargs={}, response_metadata={}, id='3aab74c8-db75-4621-be92-1b2f38b1a246'),
#   AIMessage(content='Your name is Aki. We just introduced ourselves, remember?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 80, 'total_tokens': 94, 'completion_time': 0.057043414, 'completion_tokens_details': None, 'prompt_time': 0.005170303, 'prompt_tokens_details': None, 'queue_time': 0.075445176, 'total_time': 0.062213717}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019e2c9f-a851-7f82-9de0-dbf6613339d0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 80, 'output_tokens': 14, 'total_tokens': 94})]}
